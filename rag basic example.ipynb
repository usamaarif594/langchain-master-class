# %%
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Chroma

# %%
api = 'AIzaSyB1p0yVl-BSf7-AGGTdMBBHb5tjsKlEv4s'

# %%
current_dir = os.path.dirname(os.path.abspath("__file__"))
file_path = os.path.join(current_dir, "books", "odyssey.txt")
persistent_directory = os.path.join(current_dir, "db", "chroma_db")

# Check if the Chroma vector store already exists
if not os.path.exists(persistent_directory):
    print("Persistent directory does not exist. Initializing vector store...")

    # Ensure the text file exists
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"The file {file_path} does not exist. Please check the path.")

    # Read the text content from the file
    # try:
    loader = TextLoader(file_path, encoding='utf-8')  # Try with UTF-8 encoding
    documents = loader.load()
   
    # Split the document into chunks
    text_splitter = CharacterTextSplitter(chunk_size=700, chunk_overlap=0)
    docs = text_splitter.split_documents(documents)

    # Display information about the split documents
    print("\n--- Document Chunks Information ---")
    print(f"Number of document chunks: {len(docs)}")
    embeddings=GoogleGenerativeAIEmbeddings(model="models/embedding-001",google_api_key=api)
    print("\n--- Finished creating embeddings ---")
    # setting database
    db=Chroma.from_documents(docs,embeddings,persist_directory=persistent_directory
    )
    print("\n--- Finished creating vector store ---")
# Out:
# Created a chunk of size 1141, which is longer than the specified 700
# Created a chunk of size 2086, which is longer than the specified 700
# Created a chunk of size 1121, which is longer than the specified 700
# Created a chunk of size 914, which is longer than the specified 700
# Created a chunk of size 1366, which is longer than the specified 700
# Created a chunk of size 827, which is longer than the specified 700
# Created a chunk of size 816, which is longer than the specified 700
# Created a chunk of size 979, which is longer than the specified 700
# Created a chunk of size 862, which is longer than the specified 700
# Created a chunk of size 1011, which is longer than the specified 700
# Created a chunk of size 1639, which is longer than the specified 700
# Created a chunk of size 1219, which is longer than the specified 700
# Created a chunk of size 1875, which is longer than the specified 700
# Created a chunk of size 713, which is longer than the specified 700
# Created a chunk of size 1307, which is longer than the specified 700
# Created a chunk of size 2271, which is longer than the specified 700
# Created a chunk of size 872, which is longer than the specified 700
# Created a chunk of size 1430, which is longer than the specified 700
# Created a chunk of size 877, which is longer than the specified 700
# Created a chunk of size 763, which is longer than the specified 700
# Created a chunk of size 1763, which is longer than the specified 700
# Created a chunk of size 755, which is longer than the specified 700
# Created a chunk of size 711, which is longer than the specified 700
# Created a chunk of size 793, which is longer than the specified 700
# Created a chunk of size 1575, which is longer than the specified 700
# Created a chunk of size 1028, which is longer than the specified 700
# Created a chunk of size 779, which is longer than the specified 700
# Created a chunk of size 1149, which is longer than the specified 700
# Created a chunk of size 1199, which is longer than the specified 700
# Created a chunk of size 1604, which is longer than the specified 700
# Created a chunk of size 958, which is longer than the specified 700
# Created a chunk of size 730, which is longer than the specified 700
# Created a chunk of size 1832, which is longer than the specified 700
# Created a chunk of size 896, which is longer than the specified 700
# Created a chunk of size 728, which is longer than the specified 700
# Created a chunk of size 780, which is longer than the specified 700
# Created a chunk of size 805, which is longer than the specified 700
# Created a chunk of size 724, which is longer than the specified 700
# Created a chunk of size 856, which is longer than the specified 700
# Created a chunk of size 932, which is longer than the specified 700
# Created a chunk of size 1093, which is longer than the specified 700
# Created a chunk of size 782, which is longer than the specified 700
# Created a chunk of size 1995, which is longer than the specified 700
# Created a chunk of size 836, which is longer than the specified 700
# Created a chunk of size 778, which is longer than the specified 700
# Created a chunk of size 776, which is longer than the specified 700
# Created a chunk of size 1463, which is longer than the specified 700
# Created a chunk of size 1098, which is longer than the specified 700
# Created a chunk of size 805, which is longer than the specified 700
# Created a chunk of size 812, which is longer than the specified 700
# Created a chunk of size 737, which is longer than the specified 700
# Created a chunk of size 722, which is longer than the specified 700
# Created a chunk of size 772, which is longer than the specified 700
# Created a chunk of size 910, which is longer than the specified 700
# Created a chunk of size 922, which is longer than the specified 700
# Created a chunk of size 1053, which is longer than the specified 700
# Created a chunk of size 892, which is longer than the specified 700
# Created a chunk of size 754, which is longer than the specified 700
# Created a chunk of size 790, which is longer than the specified 700
# Created a chunk of size 927, which is longer than the specified 700
# Created a chunk of size 967, which is longer than the specified 700
# Created a chunk of size 1027, which is longer than the specified 700
# Created a chunk of size 922, which is longer than the specified 700
# Created a chunk of size 891, which is longer than the specified 700
# Created a chunk of size 759, which is longer than the specified 700
# Created a chunk of size 714, which is longer than the specified 700
# Created a chunk of size 751, which is longer than the specified 700
# Created a chunk of size 943, which is longer than the specified 700
# Created a chunk of size 968, which is longer than the specified 700
# Persistent directory does not exist. Initializing vector store...
# Created a chunk of size 1315, which is longer than the specified 700
# Created a chunk of size 1627, which is longer than the specified 700
# Created a chunk of size 958, which is longer than the specified 700
# Created a chunk of size 1063, which is longer than the specified 700
# Created a chunk of size 941, which is longer than the specified 700
# Created a chunk of size 701, which is longer than the specified 700
# Created a chunk of size 775, which is longer than the specified 700
# Created a chunk of size 978, which is longer than the specified 700
# Created a chunk of size 799, which is longer than the specified 700
# Created a chunk of size 740, which is longer than the specified 700
# Created a chunk of size 1051, which is longer than the specified 700
# Created a chunk of size 896, which is longer than the specified 700
# Created a chunk of size 1265, which is longer than the specified 700
# Created a chunk of size 1202, which is longer than the specified 700
# Created a chunk of size 1509, which is longer than the specified 700
# Created a chunk of size 706, which is longer than the specified 700
# Created a chunk of size 859, which is longer than the specified 700
# Created a chunk of size 1153, which is longer than the specified 700
# Created a chunk of size 1043, which is longer than the specified 700
# Created a chunk of size 1336, which is longer than the specified 700
# Created a chunk of size 1111, which is longer than the specified 700
# Created a chunk of size 1205, which is longer than the specified 700
# Created a chunk of size 724, which is longer than the specified 700
# Created a chunk of size 1158, which is longer than the specified 700
# Created a chunk of size 877, which is longer than the specified 700
# Created a chunk of size 747, which is longer than the specified 700
# Created a chunk of size 979, which is longer than the specified 700
# Created a chunk of size 1004, which is longer than the specified 700
# Created a chunk of size 1155, which is longer than the specified 700
# Created a chunk of size 1085, which is longer than the specified 700
# Created a chunk of size 1064, which is longer than the specified 700
# Created a chunk of size 764, which is longer than the specified 700
# Created a chunk of size 941, which is longer than the specified 700
# Created a chunk of size 733, which is longer than the specified 700
# Created a chunk of size 971, which is longer than the specified 700
# Created a chunk of size 1078, which is longer than the specified 700
# Created a chunk of size 729, which is longer than the specified 700
# Created a chunk of size 1827, which is longer than the specified 700
# Created a chunk of size 1188, which is longer than the specified 700
# Created a chunk of size 1058, which is longer than the specified 700
# Created a chunk of size 754, which is longer than the specified 700
# Created a chunk of size 864, which is longer than the specified 700
# Created a chunk of size 905, which is longer than the specified 700
# Created a chunk of size 1226, which is longer than the specified 700
# Created a chunk of size 753, which is longer than the specified 700
# Created a chunk of size 1419, which is longer than the specified 700
# Created a chunk of size 773, which is longer than the specified 700
# Created a chunk of size 1223, which is longer than the specified 700
# Created a chunk of size 1284, which is longer than the specified 700
# Created a chunk of size 989, which is longer than the specified 700
# Created a chunk of size 1112, which is longer than the specified 700
# Created a chunk of size 1437, which is longer than the specified 700
# Created a chunk of size 1030, which is longer than the specified 700
# Created a chunk of size 774, which is longer than the specified 700
# Created a chunk of size 1094, which is longer than the specified 700
# Created a chunk of size 931, which is longer than the specified 700
# Created a chunk of size 1079, which is longer than the specified 700
# Created a chunk of size 726, which is longer than the specified 700
# Created a chunk of size 1073, which is longer than the specified 700
# Created a chunk of size 709, which is longer than the specified 700
# Created a chunk of size 1550, which is longer than the specified 700
# Created a chunk of size 1737, which is longer than the specified 700
# Created a chunk of size 817, which is longer than the specified 700
# Created a chunk of size 709, which is longer than the specified 700
# Created a chunk of size 753, which is longer than the specified 700
# Created a chunk of size 866, which is longer than the specified 700
# Created a chunk of size 839, which is longer than the specified 700
# Created a chunk of size 877, which is longer than the specified 700
# Created a chunk of size 1038, which is longer than the specified 700
# Created a chunk of size 1011, which is longer than the specified 700
# Created a chunk of size 1382, which is longer than the specified 700
# Created a chunk of size 725, which is longer than the specified 700
# Created a chunk of size 1184, which is longer than the specified 700
# Created a chunk of size 900, which is longer than the specified 700
# Created a chunk of size 851, which is longer than the specified 700
# Created a chunk of size 752, which is longer than the specified 700
# Created a chunk of size 1378, which is longer than the specified 700
# Created a chunk of size 845, which is longer than the specified 700
# Created a chunk of size 918, which is longer than the specified 700
# Created a chunk of size 736, which is longer than the specified 700
# Created a chunk of size 1052, which is longer than the specified 700
# Created a chunk of size 1402, which is longer than the specified 700
# Created a chunk of size 1047, which is longer than the specified 700
# Created a chunk of size 990, which is longer than the specified 700
# Created a chunk of size 948, which is longer than the specified 700
# Created a chunk of size 868, which is longer than the specified 700
# Created a chunk of size 1163, which is longer than the specified 700
# Created a chunk of size 804, which is longer than the specified 700
# Created a chunk of size 869, which is longer than the specified 700
# Created a chunk of size 707, which is longer than the specified 700
# Created a chunk of size 796, which is longer than the specified 700
# Created a chunk of size 710, which is longer than the specified 700
# Created a chunk of size 1403, which is longer than the specified 700
# Created a chunk of size 1077, which is longer than the specified 700
# Created a chunk of size 773, which is longer than the specified 700
# Created a chunk of size 1588, which is longer than the specified 700
# Created a chunk of size 1228, which is longer than the specified 700
# Created a chunk of size 747, which is longer than the specified 700
# Created a chunk of size 968, which is longer than the specified 700
# Created a chunk of size 989, which is longer than the specified 700
# Created a chunk of size 1337, which is longer than the specified 700
# Created a chunk of size 897, which is longer than the specified 700
# Created a chunk of size 709, which is longer than the specified 700
# Created a chunk of size 911, which is longer than the specified 700
# Created a chunk of size 1469, which is longer than the specified 700
# Created a chunk of size 806, which is longer than the specified 700
# Created a chunk of size 833, which is longer than the specified 700
# Created a chunk of size 735, which is longer than the specified 700
# Created a chunk of size 835, which is longer than the specified 700
# Created a chunk of size 843, which is longer than the specified 700
# Created a chunk of size 1269, which is longer than the specified 700
# Created a chunk of size 1106, which is longer than the specified 700
# Created a chunk of size 753, which is longer than the specified 700
# Created a chunk of size 992, which is longer than the specified 700
# Created a chunk of size 792, which is longer than the specified 700
# Created a chunk of size 736, which is longer than the specified 700
# Created a chunk of size 785, which is longer than the specified 700
# Created a chunk of size 866, which is longer than the specified 700
# Created a chunk of size 1492, which is longer than the specified 700
# Created a chunk of size 1219, which is longer than the specified 700
# Created a chunk of size 990, which is longer than the specified 700
# Created a chunk of size 1165, which is longer than the specified 700
# Created a chunk of size 1115, which is longer than the specified 700
# Created a chunk of size 1505, which is longer than the specified 700
# Created a chunk of size 922, which is longer than the specified 700
# Created a chunk of size 990, which is longer than the specified 700
# Created a chunk of size 1549, which is longer than the specified 700
# Created a chunk of size 1309, which is longer than the specified 700
# Created a chunk of size 813, which is longer than the specified 700
# Created a chunk of size 1290, which is longer than the specified 700
# Created a chunk of size 1593, which is longer than the specified 700
# Created a chunk of size 1292, which is longer than the specified 700
# Created a chunk of size 1136, which is longer than the specified 700
# Created a chunk of size 774, which is longer than the specified 700
# Created a chunk of size 1162, which is longer than the specified 700
# Created a chunk of size 967, which is longer than the specified 700
# Created a chunk of size 1003, which is longer than the specified 700
# Created a chunk of size 1065, which is longer than the specified 700
# Created a chunk of size 1403, which is longer than the specified 700
# Created a chunk of size 1564, which is longer than the specified 700
# Created a chunk of size 1776, which is longer than the specified 700
# Created a chunk of size 1006, which is longer than the specified 700
# Created a chunk of size 1377, which is longer than the specified 700
# Created a chunk of size 1289, which is longer than the specified 700
# Created a chunk of size 727, which is longer than the specified 700
# Created a chunk of size 1727, which is longer than the specified 700
# Created a chunk of size 958, which is longer than the specified 700
# Created a chunk of size 764, which is longer than the specified 700
# Created a chunk of size 1555, which is longer than the specified 700
# Created a chunk of size 788, which is longer than the specified 700
# Created a chunk of size 871, which is longer than the specified 700
# Created a chunk of size 808, which is longer than the specified 700
# Created a chunk of size 1619, which is longer than the specified 700
# Created a chunk of size 744, which is longer than the specified 700
# Created a chunk of size 772, which is longer than the specified 700
# Created a chunk of size 1059, which is longer than the specified 700
# Created a chunk of size 1013, which is longer than the specified 700
# Created a chunk of size 1180, which is longer than the specified 700
# Created a chunk of size 721, which is longer than the specified 700
# Created a chunk of size 763, which is longer than the specified 700
# Created a chunk of size 814, which is longer than the specified 700
# Created a chunk of size 1897, which is longer than the specified 700
# Created a chunk of size 952, which is longer than the specified 700
# Created a chunk of size 1412, which is longer than the specified 700
# Created a chunk of size 739, which is longer than the specified 700
# Created a chunk of size 841, which is longer than the specified 700
# Created a chunk of size 742, which is longer than the specified 700
# Created a chunk of size 776, which is longer than the specified 700
# Created a chunk of size 800, which is longer than the specified 700
# Created a chunk of size 1740, which is longer than the specified 700
# Created a chunk of size 767, which is longer than the specified 700
# Created a chunk of size 1126, which is longer than the specified 700
# Created a chunk of size 1003, which is longer than the specified 700
# Created a chunk of size 795, which is longer than the specified 700
# Created a chunk of size 964, which is longer than the specified 700
# Created a chunk of size 786, which is longer than the specified 700
# Created a chunk of size 743, which is longer than the specified 700
# Created a chunk of size 888, which is longer than the specified 700
# Created a chunk of size 712, which is longer than the specified 700
# Created a chunk of size 1126, which is longer than the specified 700
# Created a chunk of size 1384, which is longer than the specified 700
# Created a chunk of size 704, which is longer than the specified 700
# Created a chunk of size 944, which is longer than the specified 700
# Created a chunk of size 1688, which is longer than the specified 700
# Created a chunk of size 960, which is longer than the specified 700
# Created a chunk of size 926, which is longer than the specified 700
# Created a chunk of size 710, which is longer than the specified 700
# Created a chunk of size 901, which is longer than the specified 700
# Created a chunk of size 1035, which is longer than the specified 700
# Created a chunk of size 908, which is longer than the specified 700
# Created a chunk of size 2424, which is longer than the specified 700
# Created a chunk of size 2028, which is longer than the specified 700
# Created a chunk of size 866, which is longer than the specified 700
# Created a chunk of size 1697, which is longer than the specified 700
# Created a chunk of size 2474, which is longer than the specified 700
# Created a chunk of size 1327, which is longer than the specified 700
# Created a chunk of size 1225, which is longer than the specified 700
# Created a chunk of size 1118, which is longer than the specified 700
# Created a chunk of size 768, which is longer than the specified 700
# Created a chunk of size 1999, which is longer than the specified 700
# Created a chunk of size 843, which is longer than the specified 700
# Created a chunk of size 2401, which is longer than the specified 700
# Created a chunk of size 1227, which is longer than the specified 700
# Created a chunk of size 1074, which is longer than the specified 700
# Created a chunk of size 719, which is longer than the specified 700
# Created a chunk of size 1810, which is longer than the specified 700
# Created a chunk of size 1065, which is longer than the specified 700
# Created a chunk of size 1528, which is longer than the specified 700
# Created a chunk of size 1122, which is longer than the specified 700
# Created a chunk of size 990, which is longer than the specified 700
# Created a chunk of size 2149, which is longer than the specified 700
# Created a chunk of size 1226, which is longer than the specified 700
# Created a chunk of size 801, which is longer than the specified 700
# Created a chunk of size 823, which is longer than the specified 700
# Created a chunk of size 762, which is longer than the specified 700
# Created a chunk of size 1008, which is longer than the specified 700
# Created a chunk of size 885, which is longer than the specified 700
# Created a chunk of size 733, which is longer than the specified 700
# Created a chunk of size 1504, which is longer than the specified 700
# Created a chunk of size 1119, which is longer than the specified 700
# Created a chunk of size 849, which is longer than the specified 700
# Created a chunk of size 796, which is longer than the specified 700
# Created a chunk of size 1107, which is longer than the specified 700
# Created a chunk of size 701, which is longer than the specified 700
# Created a chunk of size 925, which is longer than the specified 700
# Created a chunk of size 896, which is longer than the specified 700
# Created a chunk of size 1194, which is longer than the specified 700
# Created a chunk of size 1031, which is longer than the specified 700
# Created a chunk of size 880, which is longer than the specified 700
# Created a chunk of size 742, which is longer than the specified 700
# Created a chunk of size 967, which is longer than the specified 700
# Created a chunk of size 786, which is longer than the specified 700
# Created a chunk of size 1034, which is longer than the specified 700
# Created a chunk of size 1386, which is longer than the specified 700
# Created a chunk of size 1235, which is longer than the specified 700
# Created a chunk of size 813, which is longer than the specified 700
# Created a chunk of size 1004, which is longer than the specified 700
# Created a chunk of size 1792, which is longer than the specified 700
# Created a chunk of size 1132, which is longer than the specified 700
# Created a chunk of size 750, which is longer than the specified 700
# Created a chunk of size 1055, which is longer than the specified 700
# Created a chunk of size 1189, which is longer than the specified 700
# Created a chunk of size 880, which is longer than the specified 700
# Created a chunk of size 1528, which is longer than the specified 700
# Created a chunk of size 2049, which is longer than the specified 700
# Created a chunk of size 1097, which is longer than the specified 700
# Created a chunk of size 1860, which is longer than the specified 700
# Created a chunk of size 1296, which is longer than the specified 700
# Created a chunk of size 737, which is longer than the specified 700
# Created a chunk of size 1369, which is longer than the specified 700
# Created a chunk of size 850, which is longer than the specified 700
# Created a chunk of size 1121, which is longer than the specified 700
# Created a chunk of size 1285, which is longer than the specified 700
# Created a chunk of size 780, which is longer than the specified 700
# Created a chunk of size 811, which is longer than the specified 700
# Created a chunk of size 1736, which is longer than the specified 700
# Created a chunk of size 789, which is longer than the specified 700
# Created a chunk of size 935, which is longer than the specified 700
# Created a chunk of size 1637, which is longer than the specified 700
# Created a chunk of size 1184, which is longer than the specified 700
# Created a chunk of size 1045, which is longer than the specified 700
# Created a chunk of size 1132, which is longer than the specified 700
# Created a chunk of size 737, which is longer than the specified 700
# Created a chunk of size 1674, which is longer than the specified 700
# Created a chunk of size 808, which is longer than the specified 700
# Created a chunk of size 800, which is longer than the specified 700
# --- Document Chunks Information ---
# Number of document chunks: 1024
#
# --- Finished creating embeddings ---
#
# --- Finished creating vector store ---

# %%
print(f"Sample chunk:\n{docs[12].page_content}\n")
# Out:
# Sample chunk:
# Other difficulties will also disappear as soon as the development of
# the poem in the writer’s mind is understood. I have dealt with this at
# some length in pp. 251-261 of “The Authoress of the Odyssey”. Briefly,
# the “Odyssey” consists of two distinct poems: (1) The Return of
# Ulysses, which alone the Muse is asked to sing in the opening lines of
# the poem. This poem includes the Phaeacian episode, and the account of
# Ulysses’ adventures as told by himself in Books ix.-xii. It consists of
# lines 1-79 (roughly) of Book i., of line 28 of Book v., and thence
# without intermission to the middle of line 187 of Book xiii., at which
# point the original scheme was abandoned.

# %%
# loading existing embeddings
db=Chroma(persist_directory=persistent_directory,embedding_function=embeddings)

# %%
# retreival part
retieval=db.as_retriever(search_type="similarity_score_threshold",
         search_kwargs={"k": 3, "score_threshold": 0.5},)

# %%
query = "Who is Odysseus' wife?"

# %%
relevant_docs=retieval.invoke(query)

# %%
for i, doc in enumerate(relevant_docs, 1):
    print(f"Document {i}:\n{doc.page_content}\n")
    if doc.metadata:
        print(f"Source: {doc.metadata.get('source', 'Unknown')}\n")
# Out:
# Document 1:
# Now all the rest, as many as fled from sheer destruction, were at
#     home, and had escaped both war and sea, but Odysseus only, craving
#     for his wife and for his homeward path, the lady nymph Calypso
#     held, that fair goddess, in her hollow caves, longing to have him
#     for her lord. But when now the year had come in the courses of the
#     seasons, wherein the gods had ordained that he should return home
#     to Ithaca, not even there was he quit of labours, not even among
#     his own; but all the gods had pity on him save Poseidon, who raged
#     continually against godlike Odysseus, till he came to his own
#     country. Howbeit Poseidon had now departed for the distant
#     Ethiopians, the Ethiopians that are sundered in twain, the
#     uttermost of men, abiding some where Hyperion sinks and some where
#     he rises. There he looked to receive his hecatomb of bulls and
#     rams, there he made merry sitting at the feast, but the other gods
#     were gathered in the halls of Olympian Zeus. Then among them the
#     father of men and gods began to speak, for he bethought him in his
#     heart of noble Aegisthus, whom the son of Agamemnon, far-famed
#     Orestes, slew. Thinking upon him he spake out among the Immortals:
#     ‘Lo you now, how vainly mortal men do blame the gods! For of us
#     they say comes evil, whereas they even of themselves, through the
#     blindness of their own hearts, have sorrows beyond that which is
#     ordained. Even as of late Aegisthus, beyond that which was
#     ordained, took to him the wedded wife of the son of Atreus, and
#     killed her lord on his return, and that with sheer doom before his
#     eyes, since we had warned him by the embassy of Hermes the
#     keen-sighted, the slayer of Argos, that he should neither kill the
#     man, nor woo his wife. For the son of Atreus shall be avenged at
#     the hand of Orestes, so soon as he shall come to man’s estate and
#     long for his own country. So spake Hermes, yet he prevailed not on
#     the heart of Aegisthus, for all his good will; but now hath he paid
#     one price for all.’
#
# Source: C:\Users\DELL\langchain+Rag\books\odyssey.txt
#
# Document 2:
# And the goddess, grey-eyed Athene, answered him, saying: ‘O father,
#     our father Cronides, throned in the highest; that man assuredly
#     lies in a death that is his due; so perish likewise all who work
#     such deeds! But my heart is rent for wise Odysseus, the hapless
#     one, who far from his friends this long while suffereth affliction
#     in a sea-girt isle, where is the navel of the sea, a woodland isle,
#     and therein a goddess hath her habitation, the daughter of the
#     wizard Atlas, who knows the depths of every sea, and himself
#     upholds the tall pillars which keep earth and sky asunder. His
#     daughter it is that holds the hapless man in sorrow: and ever with
#     soft and guileful tales she is wooing him to forgetfulness of
#     Ithaca. But Odysseus yearning to see if it were but the smoke leap
#     upwards from his own land, hath a desire to die. As for thee, thine
#     heart regardeth it not at all, Olympian! What! Did not Odysseus by
#     the ships of the Argives make thee free offering of sacrifice in
#     the wide Trojan land? Wherefore wast thou then so wroth with him, O
#     Zeus?’
#
# Source: C:\Users\DELL\langchain+Rag\books\odyssey.txt
#
# Document 3:
# When he was in this plight, Ino daughter of Cadmus, also called
# Leucothea, saw him. She had formerly been a mere mortal, but had been
# since raised to the rank of a marine goddess. Seeing in what great
# distress Ulysses now was, she had compassion upon him, and, rising like
# a sea-gull from the waves, took her seat upon the raft.
#
# Source: C:\Users\DELL\langchain+Rag\books\odyssey.txt
